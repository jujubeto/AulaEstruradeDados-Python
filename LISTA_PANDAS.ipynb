# %%
import pandas as pd

# %%
dados = pd.read_excel('/dados1.xlsx')

# %%
dados
# Out:
#     Unnamed: 0     NOME  IDADE
# 0            0  JACINTO     62
# 1            1      GIL     24
# 2            2    BENTO     54
# 3            3  FENÍCIO     68
# 4            4   ISAURA     24
# 5            5   GOIABA     53
# 6            6     BETO     72
# 7            7     IONE     36
# 8            8     VILA     36
# 9            9    PAIVA     59
# 10          10     LUIZ     30
# 11          11    NEUSA     20

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados[dados['NOME'] == 'JACINTO']
# Out:
#    Unnamed: 0     NOME  IDADE
# 0           0  JACINTO     62

# %%
dados.sort_values(by='NOME')
# Out:
#     Unnamed: 0     NOME  IDADE
# 2            2    BENTO     54
# 6            6     BETO     72
# 3            3  FENÍCIO     68
# 1            1      GIL     24
# 5            5   GOIABA     53
# 7            7     IONE     36
# 4            4   ISAURA     24
# 0            0  JACINTO     62
# 10          10     LUIZ     30
# 11          11    NEUSA     20
# 9            9    PAIVA     59
# 8            8     VILA     36

# %%
dados.describe()
# Out:
#        Unnamed: 0      IDADE
# count   12.000000  12.000000
# mean     5.500000  44.833333
# std      3.605551  18.541518
# min      0.000000  20.000000
# 25%      2.750000  28.500000
# 50%      5.500000  44.500000
# 75%      8.250000  59.750000
# max     11.000000  72.000000

# %%
dados['IDADE']
# Out:
# 0     62
# 1     24
# 2     54
# 3     68
# 4     24
# 5     53
# 6     72
# 7     36
# 8     36
# 9     59
# 10    30
# 11    20
# Name: IDADE, dtype: int64

# %%
dados[dados['IDADE'] <=40]
# Out:
#     Unnamed: 0    NOME  IDADE
# 1            1     GIL     24
# 4            4  ISAURA     24
# 7            7    IONE     36
# 8            8    VILA     36
# 10          10    LUIZ     30
# 11          11   NEUSA     20

# %% [markdown]
# TRANSFORMANDO UMA COLUNA DO DATAFRAME EM UMA LISTA

# %%
nomes = list(dados['NOME'])

# %%
nomes
# Out:
# ['JACINTO',
#  'GIL',
#  'BENTO',
#  'FENÍCIO',
#  'ISAURA',
#  'GOIABA',
#  'BETO',
#  'IONE',
#  'VILA',
#  'PAIVA',
#  'LUIZ',
#  'NEUSA']

# %%
print(nomes)
# Out:
# ['JACINTO', 'GIL', 'BENTO', 'FENÍCIO', 'ISAURA', 'GOIABA', 'BETO', 'IONE', 'VILA', 'PAIVA', 'LUIZ', 'NEUSA']

# %%
print(sorted(nomes))
# Out:
# ['BENTO', 'BETO', 'FENÍCIO', 'GIL', 'GOIABA', 'IONE', 'ISAURA', 'JACINTO', 'LUIZ', 'NEUSA', 'PAIVA', 'VILA']
